# %% [markdown]
# <a href="https://colab.research.google.com/github/qozy21/AI-freelance-journey/blob/main/python/basic/Hello_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Helllo python

# %%
# ini program hello python
pirnt("hello python")

# ini program hello world !
print("hello world !")
