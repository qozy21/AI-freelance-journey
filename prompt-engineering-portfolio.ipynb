# %% [markdown]
# <a href="https://colab.research.google.com/github/qozy21/AI-freelance-journey/blob/main/prompt-engineering-portfolio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Promt yang telah ditingkatkan

# %% [markdown]
# ## Copywriting/ social media

# %% [markdown]
# **1. Prompt untuk generate 10 caption Instagram produk fashion muslimah**
#
# Buatlah 10 ide caption Instagram untuk produk fashion baru.
#
# **Tugas:**
# Hasilkan 10 caption Instagram yang berbeda, yang dirancang khusus untuk audiens wanita berhijab atau yang menyukai gaya busana sopan (modest fashion).
#
# **Gaya & Tone:**
# *   Gunakan gaya bahasa yang estetik, minimalis, elegan, dan tenang.
# *   Hindari bahasa yang terlalu menjual. Berfokuslah pada *vibe*, kenyamanan, dan keindahan detail.
# *   Gunakan kosakata yang halus, seperti "elegan", "sederhana", "esensial", "harmoni", "presisi", dan "mengalir".
#
# **Struktur Konten (Variasi):**
# Pastikan 10 caption tersebut memiliki variasi struktur konten, mencakup:
# *   Beberapa caption bersifat pengenalan produk baru (Product Launch).
# *   Beberapa caption memberikan ide padu padan (Mix & Match idea).
# *   Beberapa caption bersifat lembut, mengundang ulasan atau testimoni secara tidak langsung.
#
# **Detail Teknis:**
# *   Setiap caption harus ringkas dan padat.
# *   Sertakan beberapa emoji yang estetik dan minimalis (misal: 🤍, ✨, 🌱, 🕊️, ☕️).
# *   Sertakan 5-7 hashtag yang relevan dengan modest fashion dan estetika minimalis.
#
# **Format Output:**
# Berikan output dalam format daftar bernomor (1. sampai 10.) agar mudah dibaca.

# %% [markdown]
# **2. Prompt untuk rewrite email marketing biar conversion naik**
#
# Seorang ahli copywriter email marketing dengan pengalaman puluhan tahun menulis ulang draf email marketing untuk meningkatkan conversion rate.
#
# **Tujuan:**
# Meningkatkan konversi (jumlah klik ke landing page/pembelian) secara signifikan.
#
# **Gaya & Strategi:**
# 1.  **Fokus Utama (Benefit-Driven):** Tekankan manfaat atau solusi nyata yang didapat pembaca.
# 2.  **Gaya Penulisan (Storytelling):** Gunakan narasi yang menarik. Mulai email dengan cerita pendek tentang masalah umum yang dihadapi audiens, lalu posisikan produk/layanan sebagai solusi alami dari cerita tersebut.
# 3.  **CTA Strategy (Low Friction):** Gunakan Call to Action (Ajakan Bertindak) yang lembut dan mudah dilakukan (contoh: "Lihat caranya di sini", "Pelajari lebih lanjut").
#
# **Instruksi Tambahan:**
# *   Email harus terasa personal.
# *   Gunakan bahasa yang mudah dipahami.
# *   Buat Subjek Email yang menarik rasa penasaran dan relevan dengan cerita di dalam email.
#
# **Format Output:**
# Berikan dalam format Markdown (Bold/Italic untuk penekanan), dengan struktur:
# *   `Subjek:` [Subjek Email]
# *   `Halo [Nama Pelanggan],` [Isi Email]
# *   `[Tanda tangan/Penutup]`
#
# **[DRAF EMAIL LAMA]**

# %% [markdown]
# **3. Prompt untuk bikin thread Twitter/X tentang productivity**
#
# Bertindaklah sebagai ahli produktivitas sekaligus penulis konten Twitter/X yang piawai. Tugas Anda adalah membuat thread Twitter (serangkaian tweet yang terhubung) yang menarik dan viral.
#
# **Topik:**
# Membongkar Mitos Umum tentang Produktivitas ("Sibuk tidak sama dengan Produktif").
#
# **Gaya Bahasa:**
# *   Minimalis, ringkas, dan tajam (crisp).
# *   Gunakan kalimat pendek dan langsung pada intinya.
# *   Banyak menggunakan *white space* (jarak antar baris) agar mudah dibaca cepat di ponsel.
# *   Gunakan emoji yang minimalis dan relevan (misal: 💡, ❌, ✅, 👇).
#
# **Struktur Thread:**
# *   **Tweet 1 (Hook/Pengait):** Pernyataan berani yang langsung menarik perhatian dan menjanjikan solusi. (Contoh: "Mitos produktivitas terbesar yang merusak hidup Anda:...")
# *   **Tweet 2-5 (Step-by-Step Guide):** Penjelasan langkah demi langkah cara membedakan sibuk dan produktif, serta cara mengimplementasikan produktivitas yang efektif (bukan sekadar sibuk).
# *   **Tweet Terakhir (CTA/Penutup):** Ringkasan singkat dan ajakan untuk me-retweet, follow, atau meninggalkan komentar.
#
# **Instruksi Tambahan:**
# *   Thread harus terdiri dari total 6 tweet.
# *   Setiap tweet tidak boleh lebih dari 280 karakter.
# *   Gunakan penomoran (1/6, 2/6, dst.) di setiap tweet jika perlu.
# *   Pastikan alur cerita mengalir logis.
#
# **Output:**
# Hasilkan 6 tweet terpisah yang siap diposting.

# %% [markdown]
# ## Content creation

# %% [markdown]
# **1. Prompt untuk artikel blog 1000 kata SEO-friendly (topik bebas)**
#
# Bertindaklah sebagai Senior Content Strategist dan SEO Expert. Tugas Anda adalah menulis artikel blog mendalam sebanyak 1000 kata mengenai masa depan industri Content Creation.
#
# **Topik:** "Masa Depan Content Creation 2025: Tren, Teknologi, dan Cara Bertahan di Era AI"
#
# **Kriteria Penulisan:**
# 1. **Gaya Bahasa (Profesional & Otoritatif):** Gunakan nada bicara pakar industri. Hindari kata-kata klise. Gunakan data berbasis tren tahun 2025, argumen yang kuat, dan analisis mendalam.
# 2. **Sudut Pandang (Trend Masa Depan):** Fokus pada bagaimana kreator harus beradaptasi dengan AI Generatif, ekonomi kreator yang terdesentralisasi, dan pentingnya "Human-Centric Content" di tengah banjir konten otomatis.
# 3. **Struktur SEO (Listicle):** Gunakan struktur poin-poin besar (misal: "5 Tren Utama...") agar artikel mudah dipindai (scannable) oleh pembaca dan mesin pencari.
#
# **Struktur Artikel:**
# - **Judul yang Menarik SEO:** Gunakan angka dan kata kunci yang kuat.
# - **Pendahuluan:** Gambaran lanskap konten di tahun 2025 dan mengapa strategi lama sudah tidak relevan.
# - **Batang Tubuh (Listicle 5-7 Poin Utama):** Sertakan sub-header (H2 dan H3) yang mengandung kata kunci. Bahas topik seperti: Hyper-personalization, AI-Human Collaboration, Multi-platform Synergies, dan Community-led Growth.
# - **Analisis Mendalam:** Di setiap poin, berikan penjelasan mengapa tren ini terjadi dan dampaknya bagi kreator.
# - **Kesimpulan:** Ringkasan strategi yang harus diambil sekarang untuk tetap relevan.
# - **FAQ:** Sertakan 3-5 pertanyaan umum tentang masa depan content creation untuk meningkatkan skor SEO.
#
# **Instruksi SEO Teknis:**
# - Pastikan kepadatan kata kunci natural.
# - Gunakan LSI (Latent Semantic Indexing) seperti: "Algoritma", "Engagement", "Personal Branding", "Generative AI", dan "Digital Ecosystem".
# - Buat Meta Description singkat (max 155 karakter) di akhir artikel.
#
# **Bahasa:** Indonesia (Formal/Baku).

# %% [markdown]
# **2. Prompt untuk outline YouTube script**
#
# Bertindaklah sebagai Scriptwriter YouTube profesional yang ahli dalam teknik storytelling dan retensi penonton tinggi.
#
# **Tugas:**
# Buatlah outline naskah video YouTube yang detail untuk konten REVIEW PRODUK/JASA.
#
# **Topik/Produk:** [MASUKKAN NAMA PRODUK DI SINI]
#
# **Gaya & Struktur:**
# 1. **Penyampaian (Sinematik & Dramatis):** Gunakan narasi yang kuat, penuh penekanan pada detail, suasana (ambience), dan transisi perasaan. Fokus pada estetika penggunaan produk.
# 2. **Strategi Hook (Problem-First):** Awali video dengan menonjolkan frustrasi atau masalah besar yang dialami pengguna sebelum menemukan produk ini. Buat penonton merasa "Ini saya banget."
# 3. **Struktur Outline:**
#     *   **The Hook (0:00 - 1:00):** Visualisasi masalah dengan dramatis. Pertanyaan retoris yang menggugah emosi.
#     *   **The Introduction:** Pengenalan produk sebagai "cahaya di ujung terowongan" tanpa memberikan semua detail sekaligus.
#     *   **The Cinematic Deep Dive (Body):** Review fitur utama yang dibungkus dalam skenario penggunaan nyata. Tekankan pada pengalaman sensorik (suara, tampilan, rasa).
#     *   **The Conflict/Reality Check:** Bahas kekurangan produk secara jujur namun tetap dengan nada sinematik (kejujuran yang berwibawa).
#     *   **The Transformation/Result:** Bagaimana hidup berubah setelah menggunakan produk ini.
#     *   **The Final Verdict & CTA:** Kesimpulan yang kuat dan ajakan bertindak yang emosional.
#
# **Instruksi Tambahan:**
# - Berikan saran visual (B-Roll) untuk setiap segmen agar mendukung suasana sinematik.
# - Gunakan bahasa Indonesia yang elegan namun tetap mudah dipahami.
# - Fokus pada "Show, Don't Just Tell".
#
# **Format Output:**
# Buat dalam bentuk poin-poin outline per segmen waktu dengan kolom [Visual Suggestion] dan [Narration Point].

# %% [markdown]
# **3. Prompt untuk summarize PDF panjang jadi bullet points**
#
# \### Peran Prompt: Analis Senior & Ahli Strategi Dokumen
#
# **Tugas:**
# Ringkas dokumen PDF yang diberikan menjadi poin-poin yang terorganisir, tajam, dan siap ditindaklanjuti.
#
# **Struktur Output (Wajib):**
# Gunakan format **Categorized/Nested Bullet Points** dengan pembagian sebagai berikut:
#
# 1.  **Ringkasan Eksekutif & Temuan Kunci:** Deskripsi singkat dokumen dalam 2-3 kalimat.
# 2.  **Kategori Utama (Gunakan Sub-heading):** Kelompokkan poin-poin berdasarkan tema atau bab utama yang ditemukan dalam dokumen.
# 3.  **Langkah Tindakan (Action-Oriented):** Daftar konkret mengenai apa yang harus dilakukan atau langkah selanjutnya berdasarkan informasi dokumen ini.
# 4.  **Analisis Kritis (Critical Analysis):**
#     *   Apa kekuatan utama dari argumen/data dalam dokumen ini?
#     *   Apakah ada celah, kekurangan, atau bias yang perlu diwaspadai?
#     *   Bagaimana relevansi informasi ini terhadap konteks industri/tren saat ini di tahun 2025?
#
# **Instruksi Khusus:**
# - Fokus pada kualitas daripada kuantitas; ambil inti sari yang paling berdampak.
# - Jika ada data statistik atau angka penting, wajib dicantumkan dalam poin terkait.
# - Gunakan bahasa yang lugas, profesional, dan objektif namun kritis.
# - Pastikan setiap poin memberikan nilai tambah (bukan sekadar pengulangan kalimat teks).
#
# **Bahasa:** Indonesia.
#
# [LAMPIRKAN PDF ATAU TEMPEL TEKS PDF DI SINI]

# %% [markdown]
# ## Business Automation

# %% [markdown]
# **1. Prompt untuk generate ide nama brand + tagline**
#
# Bertindaklah sebagai Brand Identity Consultant dan Naming Expert khusus industri SaaS dan Teknologi.
#
# Tugas Anda adalah menciptakan 10 ide nama brand unik beserta tagline untuk bisnis di bidang: **Business Automation**.
#
# **Kriteria Nama Brand (Modern, Futuristik, Akronim):**
# 1. Nama harus terdengar canggih, mutakhir, dan profesional.
# 2. Fokus pada struktur **Akronim** atau singkatan yang bermakna (contoh: "S.Y.S" dari Smart Yield System).
# 3. Nama harus pendek (maksimal 2-3 suku kata saat diucapkan).
# 4. Berikan kepanjangan/makna di balik setiap akronim tersebut.
#
# **Kriteria Tagline (Berorientasi Hasil/Result-Driven):**
# 1. Tagline harus menonjolkan keuntungan nyata seperti efisiensi waktu, penghematan biaya, atau peningkatan profit.
# 2. Hindari kata-kata yang terlalu abstrak; fokus pada hasil akhir yang dirasakan klien.
#
# **Struktur Output (Tabel):**
# Tampilkan hasil dalam format tabel agar mudah dibandingkan:

# %% [markdown]
# **2. Prompt untuk analisis SWOT bisnis kecil**
#
# Bertindaklah sebagai Konsultan Strategi Bisnis untuk UMKM. Tugas Anda adalah melakukan analisis SWOT mendalam dan menyusun Matriks TOWS untuk bisnis kecil saya.
#
# **Profil Bisnis:** [MASUKKAN JENIS BISNIS ANDA DI SINI, misal: Kedai Kopi atau Toko Pakaian]
# **Model Bisnis:** Hybrid (Memiliki kehadiran fisik/offline dan aktif secara digital/online).
#
# **Langkah 1: Analisis SWOT Holistik**
# Identifikasi faktor-faktor internal dan eksternal secara detail:
# - **Strengths (Kekuatan):** Keunggulan internal di toko fisik dan aset digital.
# - **Weaknesses (Kelemahan):** Hambatan internal yang perlu diperbaiki.
# - **Opportunities (Peluang):** Tren pasar 2025, teknologi baru, dan potensi ekspansi hybrid.
# - **Threats (Ancaman):** Kompetitor, perubahan algoritma, atau kondisi ekonomi makro.
#
# **Langkah 2: Strategi TOWS (Actionable)**
# Berdasarkan temuan SWOT, buatlah strategi kombinasi sebagai berikut:
# 1. **Strategi SO (Kekuatan-Peluang):** Bagaimana menggunakan kekuatan internal untuk memanfaatkan peluang eksternal?
# 2. **Strategi WO (Kelemahan-Peluang):** Bagaimana memperbaiki kelemahan internal dengan memanfaatkan peluang eksternal?
# 3. **Strategi ST (Kekuatan-Ancaman):** Bagaimana kekuatan internal dapat memitigasi ancaman eksternal?
# 4. **Strategi WT (Kelemahan-Ancaman):** Rencana defensif untuk meminimalkan kelemahan dan menghindari ancaman.
#
# **Instruksi Tambahan:**
# - Berikan saran spesifik mengenai integrasi online-to-offline (O2O).
# - Gunakan bahasa yang praktis dan bisa langsung dieksekusi oleh pemilik bisnis kecil.
# - Pastikan analisis relevan dengan perilaku konsumen tahun 2025 yang sangat bergantung pada efisiensi digital namun tetap menghargai pengalaman fisik.
#
# **Format Output:**
# Gunakan tabel untuk SWOT, dan daftar poin terstruktur untuk Strategi TOWS.

# %% [markdown]
# **3. Prompt untuk bikin cold email outreach**
#
# Bertindaklah sebagai Ahli Outreach dan Spesialis Networking Profesional. Tugas Anda adalah menulis draf cold email yang terasa personal, ringan, dan manusiawi.
#
# **Target Audiens:** [MASUKKAN TARGET, misal: CEO Startup AI atau Manajer Kreatif]
#
# **Kriteria Email:**
# 1. **Pendekatan (Soft Intro/Networking):** Jangan langsung berjualan. Fokuslah pada membangun koneksi atau menunjukkan apresiasi terhadap pekerjaan/perusahaan mereka. Tujuannya adalah membuka pintu diskusi, bukan langsung menutup penjualan.
# 2. **Gaya Bahasa (Casual & Brief):** Gunakan nada bicara yang santai namun tetap sopan, seperti mengirim pesan di LinkedIn. Panjang email tidak boleh lebih dari 100-120 kata. Hindari kata-kata pemasaran yang muluk-muluk.
# 3. **Struktur Email:**
#     - **Subject Line:** Harus pendek, menarik rasa penasaran, dan tidak terlihat seperti iklan (Gunakan huruf kecil semua atau gaya personal).
#     - **Opening:** Referensi spesifik tentang apa yang mereka lakukan (Pencapaian, artikel, atau visi perusahaan).
#     - **The Bridge:** Hubungkan ketertarikan Anda dengan apa yang Anda kerjakan secara singkat.
#     - **Call to Action (CTA):** Gunakan pendekatan "Low Friction" (misal: "Boleh saya tanya satu hal tentang [Topik]?" atau "Tertarik untuk bertukar pikiran sebentar?").
#
# **Instruksi Tambahan:**
# - Hindari kalimat pembuka klise seperti "I hope this email finds you well."
# - Buat 3 variasi Subject Line yang berbeda.
# - Gunakan bahasa yang membuat penerima merasa bahwa email ini ditulis khusus hanya untuk mereka (bukan hasil copy-paste massal).
#
# **Bahasa:** [TENTUKAN: Indonesia atau Inggris]

# %% [markdown]
# ## Coding Helper

# %% [markdown]
# **1. Prompt untuk explain code yang rumit jadi bahasa awam**
#
# Bertindaklah sebagai Senior Software Engineer dan Mentor Coding yang ahli dalam menyederhanakan konsep kompleks. Tugas Anda adalah menjelaskan potongan kode (snippet) yang rumit agar mudah dipahami oleh seorang Junior Developer.
#
# **Kode yang akan dijelaskan:**
#
# [TEMPELKAN KODE ANDA DI SINI]
#
# **Instruksi Penjelasan:**
#
# 1. **Analogi Dunia Nyata:** Mulailah dengan memberikan analogi sederhana yang mewakili logika keseluruhan kode ini. Hubungkan dengan aktivitas sehari-hari agar konsep dasarnya tertangkap lebih dulu.
# 2. **Penjelasan Alur Logika (Logic Flow):** Jelaskan bagaimana data mengalir dalam kode ini dari awal hingga akhir. Fokus pada "bagaimana" variabel berubah dan "mengapa" fungsi-fungsi tertentu dipanggil dalam urutan tersebut.
# 3. **Komentar Baris demi Baris:** Tampilkan kembali kode tersebut, namun tambahkan komentar yang sangat jelas di samping setiap baris atau blok kode penting. Gunakan bahasa yang teknis namun mudah dipahami (Junior-friendly).
# 4. **Konsep Kunci:** Identifikasi 1-2 konsep pemrograman penting yang digunakan dalam kode ini (misal: Rekursi, Asynchronous, atau Closure) dan berikan definisi singkatnya.
#
# **Gaya Bahasa:**
# - Edukatif, suportif, dan teknis namun tidak mengintimidasi.
# - Gunakan bahasa Indonesia yang santai tapi profesional.
#
# **Format Output:**
# - Bagian 1: Analogi Sederhana.
# - Bagian 2: Penjelasan Alur (Step-by-step).
# - Bagian 3: Kode dengan Komentar Penjelasan.
# - Bagian 4: Kesimpulan Konsep Penting.

# %% [markdown]
# **2. Prompt untuk debug error Python**
#
# Bertindaklah sebagai Senior Python Developer dan Pakar Debugging. Tugas Anda adalah membantu saya memperbaiki error Python yang saya hadapi.
#
# **Masalah:**
# - Kode Python:
# [TEMPELKAN KODE ANDA DI SINI]
#
# - Pesan Error (Traceback):
# [TEMPELKAN PESAN ERROR/TRACEBACK DI SINI]
#
# **Instruksi Debugging:**
# 1. **Analisis Akar Masalah (Root Cause Analysis):** Jelaskan secara mendalam mengapa error ini terjadi. Apa yang salah dengan logika atau sintaks pada kode asli sehingga Python tidak bisa mengeksekusinya?
# 2. **Perbandingan Side-by-Side:** Tampilkan perbandingan antara kode lama (sebelum diperbaiki) dan kode baru (sesudah diperbaiki). Gunakan blok kode yang jelas agar perbedaan terlihat menonjol.
# 3. **Penjelasan Perbaikan:** Berikan poin-poin penjelasan mengenai perubahan apa saja yang Anda lakukan dan mengapa solusi tersebut efektif untuk menghilangkan error tersebut.
# 4. **Saran Pencegahan:** Berikan tips singkat atau praktik terbaik (Best Practices) agar saya tidak mengulangi kesalahan serupa di masa mendatang.
#
# **Gaya Bahasa:**
# - Profesional, teknis, namun tetap mudah dipahami.
# - Gunakan terminologi Python yang tepat (misal: "IndentationError", "Type Mismatch", "Scope", dll).
#
# **Format Output:**
# - Bagian 1: Penjelasan Error (Akar Masalah).
# - Bagian 2: Perbandingan Kode (Lama vs Baru).
# - Bagian 3: Rincian Perbaikan.
# - Bagian 4: Tips Pro-aktif.

# %% [markdown]
# **3. Prompt untuk convert code Python ke JavaScript**
#
# \### Peran: Senior Full-stack Developer & Migration Expert
#
# **Tugas:**
# Konversi kode Python berikut menjadi kode JavaScript/TypeScript yang dioptimasi untuk framework spesifik.
#
# **Spesifikasi Target:**
# 1. **Lingkungan/Framework:** [MASUKKAN FRAMEWORK: misal React/Next.js/Vue] (1. C)
# 2. **Gaya Penulisan:** TypeScript (Type-safe) menggunakan standar ES2025 terbaru. (2. C)
# 3. **Library Mapping:** Identifikasi library Python yang digunakan (seperti Pandas, Requests, atau BeautifulSoup) dan petakan ke library ekosistem JavaScript yang setara (seperti Danfo.js, Axios, atau Cheerio). (3. B)
#
# **Instruksi Konversi:**
# - Gunakan **Type Interfaces** untuk semua struktur data.
# - Pastikan logika *asynchronous* Python dikonversi secara benar menggunakan `async/await`.
# - Jika targetnya adalah framework UI (seperti React), sesuaikan logika fungsi menjadi *Hooks* atau *States* yang relevan.
# - Berikan penjelasan singkat mengenai perbedaan cara kerja antara library Python asli dengan library JS penggantinya.
#
# **Kode Python Asli:**
# [TEMPELKAN KODE PYTHON ANDA DI SINI]
#
# **Format Output:**
# 1. **Library Dependencies:** Daftar package yang perlu di-install (npm/yarn).
# 2. **TypeScript Code:** Blok kode hasil konversi.
# 3. **Konfigurasi & Catatan:** Penjelasan mengenai pemetaan library dan tips implementasi di framework target.

# %% [markdown]
# ## Personal Use

# %% [markdown]
# **1. Prompt meal plan sehat murah untuk pekerja kantor**
#
# Bertindaklah sebagai Ahli Gizi dan Penasihat Keuangan Keluarga. Tugas Anda adalah membuat meal plan (jadwal makan) untuk 7 hari yang dirancang khusus bagi pekerja kantor.
#
# **Kriteria Meal Plan:**
# 1. **Nutrisi (Balanced Diet):** Setiap hidangan harus mengandung karbohidrat kompleks, protein (nabati/hewani), dan serat yang cukup untuk menjaga fokus kerja.
# 2. **Waktu (15-Minute Meals):** Resep harus praktis dan bisa disiapkan dalam maksimal 15 menit di pagi hari atau malam sebelumnya.
# 3. **Anggaran (Value for Money):** Gunakan bahan makanan yang terjangkau namun berkualitas tinggi (misal: ayam, ikan lokal, telur, kacang-kacangan, dan sayuran musiman).
# 4. **Konteks Pekerja Kantor:** Masukkan ide menu yang "mudah dibawa" (portable) dan tidak cepat basi saat disimpan di suhu ruang atau kulkas kantor.
#
# **Struktur Output:**
# - **Daftar Belanja Mingguan:** Kelompokkan berdasarkan kategori (Protein, Karbohidrat, Sayur, Bumbu) agar efisien saat belanja di pasar/supermarket.
# - **Jadwal Makan (Senin - Minggu):** Tabel berisi menu Sarapan, Makan Siang (Bekal), dan Makan Malam.
# - **Tips Masak Cepat:** Berikan 3 trik sederhana agar persiapan makan tidak melebihi 15 menit (misal: teknik potong sayur atau bumbu dasar).
# - **Estimasi Biaya:** Berikan gambaran kasar bagaimana anggaran dikelola agar tetap hemat namun bergizi.
#
# **Instruksi Tambahan:**
# - Hindari menu yang terlalu banyak gorengan.
# - Pastikan bahan makanan bisa saling dikombinasikan (satu bahan bisa untuk beberapa menu) untuk meminimalkan sisa makanan (zero waste).
#
# Bahasa: Indonesia.

# %% [markdown]
# **2. Prompt belajar roadmap karir**
#
# \#Peran: Senior Career Coach & Solopreneur Strategist (Edisi 2025)
#
# **Tugas:**
# Buatlah roadmap belajar dan pengembangan karier selama 12 bulan (1 tahun) untuk menjadi seorang Freelancer/Solopreneur yang sukses dan kompetitif.
#
# **Target Profesi:**
# [MASUKKAN PROFESI TARGET ANDA, misal: Digital Marketer atau AI Consultant]
#
# **Kriteria Roadmap (T-Shaped Mastery):**
# 1. **Pondasi (Horizontal Bar):** Identifikasi 5 skill umum yang harus dikuasai untuk mendukung bisnis mandiri (misal: Personal Branding, Sales/Negotiation, Basic Finance, AI Tools Productivity, dan Networking).
# 2. **Keahlian Dalam (Vertical Bar):** Tentukan satu spesialisasi teknis utama yang akan menjadi nilai jual unik (Unique Selling Point) di pasar.
# 3. **Timeline (12 Bulan):** Bagi menjadi 4 kuartal:
#     - **Q1 (Preparation):** Fokus pada pembelajaran dasar dan riset pasar.
#     - **Q2 (Portofolio Build):** Fokus pada pembuatan proyek nyata dan pembuktian skill.
#     - **Q3 (Launch & Client Acquisition):** Fokus pada strategi pemasaran diri dan mendapatkan klien pertama.
#     - **Q4 (Scaling & Optimization):** Fokus pada sistemasi kerja dan peningkatan tarif jasa.
#
# **Instruksi Tambahan:**
# - Masukkan rekomendasi sumber belajar (kursus online, buku, atau komunitas) yang relevan untuk tahun 2025.
# - Berikan saran tentang cara memanfaatkan AI untuk mengotomatisasi pekerjaan administratif agar tetap produktif sendirian.
# - Sertakan "Milestone" atau indikator keberhasilan di setiap akhir kuartal.
# - Gunakan nada bicara yang memotivasi, praktis, dan berorientasi pada hasil.
#
# **Bahasa:** Indonesia.
